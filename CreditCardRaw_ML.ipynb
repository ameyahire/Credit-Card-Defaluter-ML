# %%
import pandas as pd

# %%
#link of Data.csv- "https://github.com/vaishnavi-jaishwal/Credit-Card-Defaults-Analysis-Dashboard-Power-BI?form=MG0AV3"
data = pd.read_csv('Data.csv')
data.head()
# Out:
#   Unnamed: 0         X1   X2         X3        X4   X5     X6     X7     X8  \
# 0         ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3
# 1          1      20000    2          2         1   24      2      2     -1
# 2          2     120000    2          2         2   26     -1      2      0
# 3          3      90000    2          2         2   34      0      0      0
# 4          4      50000    2          2         1   37      0      0      0
#
#       X9  ...        X16        X17       X18       X19       X20       X21  \
# 0  PAY_4  ...  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4
# 1     -1  ...          0          0         0       689         0         0
# 2      0  ...       3455       3261         0      1000      1000      1000
# 3      0  ...      14948      15549      1518      1500      1000      1000
# 4      0  ...      28959      29547      2000      2019      1200      1100
#
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0    0
# X1            0
# X2            0
# X3            0
# X4            0
# X5            0
# X6            0
# X7            0
# X8            0
# X9            0
# X10           0
# X11           0
# X12           0
# X13           0
# X14           0
# X15           0
# X16           0
# X17           0
# X18           0
# X19           0
# X20           0
# X21           0
# X22           0
# X23           0
# Y             0
# state         0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9',
#        'X10', 'X11', 'X12', 'X13', 'X14', 'X15', 'X16', 'X17', 'X18', 'X19',
#        'X20', 'X21', 'X22', 'X23', 'Y', 'state'],
#       dtype='object')

# %%
data = pd.read_csv("Data.csv", skiprows = 1)

# %%
data.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month', 'North Carolina'],
#       dtype='object')

# %%
data.columns = data.iloc[0]  # Set first row as column names
data = data[1:].reset_index(drop=True)  # Drop the first row and reset index

# %%
data.head()
# Out:
# 0  1   20000  2  2  1  24  2  2  -1  -1  ...      0      0     0    689  \
# 0  2  120000  2  2  2  26 -1  2   0   0  ...   3455   3261     0   1000
# 1  3   90000  2  2  2  34  0  0   0   0  ...  14948  15549  1518   1500
# 2  4   50000  2  2  1  37  0  0   0   0  ...  28959  29547  2000   2019
# 3  5   50000  1  2  1  57 -1  0  -1   0  ...  19146  19131  2000  36681
# 4  6   50000  1  1  2  37  0  0   0   0  ...  19619  20024  2500   1815
#
# 0      0     0     0     0  1  North Dakota
# 0   1000  1000     0  2000  1         Texas
# 1   1000  1000  1000  5000  0      Illinois
# 2   1200  1100  1069  1000  0       Florida
# 3  10000  9000   689   679  0        Alaska
# 4    657  1000  1000   800  0       Georgia
#
# [5 rows x 26 columns]

# %%
data.columns = [
    "ID", "LIMIT_BAL", "SEX", "EDUCATION", "MARRIAGE", "AGE",
    "PAY_0", "PAY_2", "PAY_3", "PAY_4", "PAY_5", "PAY_6",
    "BILL_AMT1", "BILL_AMT2", "BILL_AMT3", "BILL_AMT4", "BILL_AMT5", "BILL_AMT6",
    "PAY_AMT1", "PAY_AMT2", "PAY_AMT3", "PAY_AMT4", "PAY_AMT5", "PAY_AMT6",
    "DEFAULT_PAYMENT", "STATE"
]

# %%
data.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   2     120000    2          2         2   26     -1      2      0      0
# 1   3      90000    2          2         2   34      0      0      0      0
# 2   4      50000    2          2         1   37      0      0      0      0
# 3   5      50000    1          2         1   57     -1      0     -1      0
# 4   6      50000    1          1         2   37      0      0      0      0
#
#    ...  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  \
# 0  ...       3455       3261         0      1000      1000      1000
# 1  ...      14948      15549      1518      1500      1000      1000
# 2  ...      28959      29547      2000      2019      1200      1100
# 3  ...      19146      19131      2000     36681     10000      9000
# 4  ...      19619      20024      2500      1815       657      1000
#
#    PAY_AMT5  PAY_AMT6  DEFAULT_PAYMENT     STATE
# ...

# %%
data.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  29999.000000    29999.000000  29999.000000  29999.000000  29999.000000
# mean   15001.000000   167489.238975      1.603720      1.853128      1.551885
# std     8660.109699   129747.029798      0.489132      0.790361      0.521969
# min        2.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7501.500000    50000.000000      1.000000      1.000000      1.000000
# 50%    15001.000000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.500000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  29999.000000  29999.000000  29999.000000  29999.000000  29999.000000
# mean      35.485883     -0.016767     -0.133838     -0.166172     -0.220641
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               29999 non-null  int64
#  1   LIMIT_BAL        29999 non-null  int64
#  2   SEX              29999 non-null  int64
#  3   EDUCATION        29999 non-null  int64
#  4   MARRIAGE         29999 non-null  int64
#  5   AGE              29999 non-null  int64
#  6   PAY_0            29999 non-null  int64
#  7   PAY_2            29999 non-null  int64
#  8   PAY_3            29999 non-null  int64
#  9   PAY_4            29999 non-null  int64
#  10  PAY_5            29999 non-null  int64
#  11  PAY_6            29999 non-null  int64
#  12  BILL_AMT1        29999 non-null  int64
#  13  BILL_AMT2        29999 non-null  int64
#  14  BILL_AMT3        29999 non-null  int64
#  15  BILL_AMT4        29999 non-null  int64
#  16  BILL_AMT5        29999 non-null  int64
# ...

# %%
data.isnull().sum()
# Out:
# ID                 0
# LIMIT_BAL          0
# SEX                0
# EDUCATION          0
# MARRIAGE           0
# AGE                0
# PAY_0              0
# PAY_2              0
# PAY_3              0
# PAY_4              0
# PAY_5              0
# PAY_6              0
# BILL_AMT1          0
# BILL_AMT2          0
# BILL_AMT3          0
# BILL_AMT4          0
# BILL_AMT5          0
# BILL_AMT6          0
# PAY_AMT1           0
# PAY_AMT2           0
# PAY_AMT3           0
# PAY_AMT4           0
# PAY_AMT5           0
# PAY_AMT6           0
# DEFAULT_PAYMENT    0
# STATE              0
# dtype: int64

# %%
import numpy as np

# %%
data.columns = data.columns.str.strip()  # Remove leading/trailing spaces

# %%
col = "LIMIT_BAL"

# Compute mean & standard deviation
mean = data[col].mean()
std = data[col].std()

# Create Z-score column
data["Z_Score"] = (data[col] - mean) / std

# Show first few rows
data.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   2     120000    2          2         2   26     -1      2      0      0
# 1   3      90000    2          2         2   34      0      0      0      0
# 2   4      50000    2          2         1   37      0      0      0      0
# 3   5      50000    1          2         1   57     -1      0     -1      0
# 4   6      50000    1          1         2   37      0      0      0      0
#
#    ...  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 0  ...         0      1000      1000      1000         0      2000
# 1  ...      1518      1500      1000      1000      1000      5000
# 2  ...      2000      2019      1200      1100      1069      1000
# 3  ...      2000     36681     10000      9000       689       679
# 4  ...      2500      1815       657      1000      1000       800
#
#    DEFAULT_PAYMENT     STATE   Z-Score   Z_Score
# 0                1     Texas -0.366014 -0.366014
# ...

# %%
outliers = data[(data["Z_Score"] < -3) | (data["Z_Score"] > 3)]

# %%
data.shape
# Out:
# (29999, 28)

# %%
outliers.count()
# Out:
# ID                 130
# LIMIT_BAL          130
# SEX                130
# EDUCATION          130
# MARRIAGE           130
# AGE                130
# PAY_0              130
# PAY_2              130
# PAY_3              130
# PAY_4              130
# PAY_5              130
# PAY_6              130
# BILL_AMT1          130
# BILL_AMT2          130
# BILL_AMT3          130
# BILL_AMT4          130
# BILL_AMT5          130
# BILL_AMT6          130
# PAY_AMT1           130
# PAY_AMT2           130
# PAY_AMT3           130
# PAY_AMT4           130
# PAY_AMT5           130
# PAY_AMT6           130
# DEFAULT_PAYMENT    130
# STATE              130
# Z-Score            130
# Z_Score            130
# dtype: int64

# %%
uq = data['STATE'].unique()
len(uq)
# Out:
# 50

# %% [markdown]
# # **One Hot Encoding if using linearmodel**

# %%
HEdf = pd.get_dummies(data, columns=["STATE"], drop_first=True)

# %%
HEdf.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   2     120000    2          2         2   26     -1      2      0      0
# 1   3      90000    2          2         2   34      0      0      0      0
# 2   4      50000    2          2         1   37      0      0      0      0
# 3   5      50000    1          2         1   57     -1      0     -1      0
# 4   6      50000    1          1         2   37      0      0      0      0
#
#    ...  STATE_South Dakota  STATE_Tennessee  STATE_Texas  STATE_Utah  \
# 0  ...               False            False         True       False
# 1  ...               False            False        False       False
# 2  ...               False            False        False       False
# 3  ...               False            False        False       False
# 4  ...               False            False        False       False
#
#    STATE_Vermont  STATE_Virginia  STATE_Washington  STATE_West Virginia  \
# ...

# %% [markdown]
# # **LabelEncoding for Tress base model**

# %%
from sklearn.preprocessing import LabelEncoder
LEdf = data.copy()
encoder = LabelEncoder()
LEdf["STATE"] = encoder.fit_transform(data["STATE"])

# %%
LEdf.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   2     120000    2          2         2   26     -1      2      0      0
# 1   3      90000    2          2         2   34      0      0      0      0
# 2   4      50000    2          2         1   37      0      0      0      0
# 3   5      50000    1          2         1   57     -1      0     -1      0
# 4   6      50000    1          1         2   37      0      0      0      0
#
#    ...  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 0  ...         0      1000      1000      1000         0      2000
# 1  ...      1518      1500      1000      1000      1000      5000
# 2  ...      2000      2019      1200      1100      1069      1000
# 3  ...      2000     36681     10000      9000       689       679
# 4  ...      2500      1815       657      1000      1000       800
#
#    DEFAULT_PAYMENT  STATE   Z-Score   Z_Score
# 0                1     42 -0.366014 -0.366014
# ...

# %%
LEdf.columns = LEdf.columns.str.strip()  # Remove spaces from column names

# %% [markdown]
# # **Training the Model**

# %%
from sklearn.model_selection import train_test_split

# %%
y = data['DEFAULT_PAYMENT']

# %%
HEdf.columns = HEdf.columns.str.strip()  # Remove spaces from column names

# %%
X = HEdf.drop(['Z-Score','ID','DEFAULT_PAYMENT'],axis=1)

# %%
X.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'Z_Score',
#        'STATE_Alaska', 'STATE_Arizona', 'STATE_Arkansas', 'STATE_California',
#        'STATE_Colorado', 'STATE_Connecticut', 'STATE_Delaware',
#        'STATE_Florida', 'STATE_Georgia', 'STATE_Hawaii', 'STATE_Idaho',
#        'STATE_Illinois', 'STATE_Indiana', 'STATE_Iowa', 'STATE_Kansas',
#        'STATE_Kentucky', 'STATE_Louisiana', 'STATE_Maine', 'STATE_Maryland',
#        'STATE_Massachusetts', 'STATE_Michigan', 'STATE_Minnesota',
#        'STATE_Mississippi', 'STATE_Missouri', 'STATE_Montana',
#        'STATE_Nebraska', 'STATE_Nevada', 'STATE_New Hampshire',
#        'STATE_New Jersey', 'STATE_New Mexico', 'STATE_New York',
# ...

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(max_iter = 1000)
print(model)
# Out:
# LogisticRegression(max_iter=1000)

# %%
model.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=1000)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score, precision_score, classification_report

# %%
y_predic = model.predict(X_test)

# %%
conf = confusion_matrix(y_predic,y_test)
conf
# Out:
# array([[5665, 1323],
#        [ 166,  346]])

# %%
a_score = accuracy_score(y_test,y_predic)
a_score
# Out:
# 0.8014666666666667

# %%
p_score = precision_score(y_test,y_predic)
p_score
# Out:
# 0.67578125

# %%
print(classification_report(y_test,y_predic))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.97      0.88      5831
#            1       0.68      0.21      0.32      1669
#
#     accuracy                           0.80      7500
#    macro avg       0.74      0.59      0.60      7500
# weighted avg       0.78      0.80      0.76      7500
